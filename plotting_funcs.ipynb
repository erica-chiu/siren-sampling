# %%
# %matplotlib notebook

import numpy as np
import h5py
import matplotlib.pyplot as plt
import math

# %%
data = h5py.File('check_sdf/heart.hdf5', 'r')
negative_values = np.array(data['negative_values'])
nonnegative_values = np.array(data['nonnegative_values'])

# %%
x = negative_values[:,0,0]
y = negative_values[:,0,1]
z = negative_values[:, 0, 2]

fig = plt.figure(figsize=(8,8))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
